# %%
from openai import OpenAI
from openai import AsyncOpenAI

# %%
runpod_url = "https://tvjch63jlzhfxz-8000.proxy.runpod.net/"

# %%
model_name = "openai/gpt-oss-20b"

# %%
client = OpenAI(
    base_url =f"{runpod_url}v1",
    api_key = "EMPTY"
)

# %%
is_resoning = False
for chunk in client.chat.completions.create(
    model = "openai/gpt-oss-20b",
    messages = [
        {"role": "user", "content": "간단한 로또 추천기 파이선 코드를 작성해줘"}
    ],
    stream = True,
    
):
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end='', flush=True)
# Out:
# 아래는 **Python 3** 로써 간단한 로또 번호 추천기입니다.
# - 로또 표준(1~45 중 6개 숫자) 가정
# - `random.sample` 로 중복 없이 무작위 번호를 뽑음
# - 한 번에 여러 개(예: 3개) 추첨 결과를 한 번에 보여줄 수 있도록 `draw` 인자를 받음
#
# ```python
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
#
# """
# 로또 번호 추천기 (Python 3)
#
# 사용법
# ------
# 1. 저장한 뒤 터미널에서 실행:
#    $ python lotto_recommender.py
#
# 2. 다른 프로그램에서 모듈화 하여 사용:
#    >>> import lotto_recommender
#    >>> lotto_recommender.draw(4)       # 4개의 추첨 결과를 리스트 형태로 반환
#
# 특징
# ----
# - 1~45 사이의 숫자 중 중복 없이 6개를 무작위로 뽑음
# - `draw(num)` 에서 `num` 은 가져오려는 추첨 횟수
# - 매 실행 시마다 다른 번호를 생성 (시드값이 시스템 시계 기준)
#
# """
#
# import random
# from typing import List
#
# # 로또의 범위와 한 번에 뽑을 수 있는 숫자를 상수화해두면 수정이 편리합니다.
# LOTTO_MIN = 1          # 최소 숫자
# LOTTO_MAX = 45         # 최대 숫자
# NUM_PER_TICKET = 6     # 한 장(로또표)당 숫자 개수
#
# def draw(num: int = 1) -> List[List[int]]:
#     """
#     로또 번호를 무작위로 추출합니다.
#
#     Parameters
#     ----------
#     num : int, optional
#         추첨 횟수(몇장의 로또 번호를 만들지). 기본값은 1.
#
#     Returns
# ...

# %%
client = AsyncOpenAI(
    base_url = "https://tvjch63jlzhfxz-8000.proxy.runpod.net/v1",
    api_key = "EMPTY"
)

# %%
async for chunk in await client.chat.completions.create(
    model = "openai/gpt-oss-20b",
    messages = [
        {"role": "user", "content": "간단한 로또 추천기 파이선 코드를 작성해줘"}
    ],
    stream = True
):
    if chunk.choices[0].delta.content:
        print(chunk.choices[0].delta.content, end='', flush=True)
# Out:
# 아래 예시는 **한국 로또**(1~45번 중 6개를 무작위로 뽑는 방식)에 맞춰서,
# * 같은 번호가 중복되지 않도록
# * 사용자가 제외하고 싶은 번호를 입력할 수 있도록
#
# 간단히 구현한 코드입니다.
# **필요한 라이브러리** : `random` (표준 라이브러리)
#
# ```python
# #!/usr/bin/env python3
# # -*- coding: utf-8 -*-
#
# """
# 간단한 로또 추천기
# Author : ChatGPT
# """
#
# import random
# from typing import List, Set
#
# def generate_lotto_numbers(avoid: Set[int] = None) -> List[int]:
#     """
#     1~45 중에서 6개의 무작위 번호를 반환합니다.
#     :param avoid: 제외할 번호의 집합 (예: {3, 7, 11})
#     :return: 가운데 정렬된 오름차순 리스트
#     """
#     if avoid is None:
#         avoid = set()
#
#     # 1~45의 모든 번호에서 avoid 를 제외한 리스트를 만든다
#     available_numbers = [num for num in range(1, 46) if num not in avoid]
#
#     # 가용 번호가 충분한지 확인
#     if len(available_numbers) < 6:
#         raise ValueError("제외할 번호가 너무 많아 로또 번호를 만들 수 없습니다.")
#
#     # 무작위로 6개의 번호를 선택
#     chosen = random.sample(available_numbers, 6)
#     chosen.sort()  # 오름차순 정렬
#     return chosen
#
#
# def main():
#     # 사용자가 제외하고 싶은 번호를 입력(공백으로 구분)
# ...
