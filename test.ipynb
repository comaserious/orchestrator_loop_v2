# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from tavily import TavilyClient

tavily_client = TavilyClient()
response = tavily_client.search("Who is Leo Messi?")

print(response)
# Out:
# {'query': 'Who is Leo Messi?', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.fcbarcelona.com/en/card/2214377/leo-messi', 'title': 'Leo Messi - FC Barcelona', 'content': "* [Barça Cafe](/en/club/facilities/barca-cafe). * [Latest](/en/football/first-team/news). * [Schedule](/en/football/first-team/schedule). * [Results](/en/football/first-team/results). * [Standings](/en/football/first-team/standings). * [Players](/en/football/first-team/players). * [Photos](/en/football/first-team/photos). * [Honours](/en/football/first-team/honours). * [First Team](/en/football/first-team/news). * [Barça Atlètic](/en/football/barca-atletic/news). * [Barça Legends](/en/football/barca-legends/contact). * [Barça Youth](/en/football/barca-youth/news). * [First Team](/en/basketball/first-team/news). * [First Team](/en/handball/first-team/news). * [First Team](/en/futsal/first-team/news). * [First Team](/en/roller-hockey/first-team/news). * [Latest](/en/footbal
# ...

# %%
print(response['results'])
# Out:
# [{'url': 'https://www.fcbarcelona.com/en/card/2214377/leo-messi', 'title': 'Leo Messi - FC Barcelona', 'content': "* [Barça Cafe](/en/club/facilities/barca-cafe). * [Latest](/en/football/first-team/news). * [Schedule](/en/football/first-team/schedule). * [Results](/en/football/first-team/results). * [Standings](/en/football/first-team/standings). * [Players](/en/football/first-team/players). * [Photos](/en/football/first-team/photos). * [Honours](/en/football/first-team/honours). * [First Team](/en/football/first-team/news). * [Barça Atlètic](/en/football/barca-atletic/news). * [Barça Legends](/en/football/barca-legends/contact). * [Barça Youth](/en/football/barca-youth/news). * [First Team](/en/basketball/first-team/news). * [First Team](/en/handball/first-team/news). * [First Team](/en/futsal/first-team/news). * [First Team](/en/roller-hockey/first-team/news). * [Latest](/en/football/first-team/news). * [Schedule](/en/football/first-team/schedule). * [Results](/en/football/first-te
# ...

# %%
response = tavily_client.search("오늘 서울 날씨는 어때?")

print(response)

# %%
from openai import OpenAI


client = OpenAI()

# %%
resp = client.responses.create(
    model = "gpt-4.1",
    tools = [
        {
            "type": "mcp",
            "server_label": "daiso-mcp",
            "server_description": "Daiso MCP server providing store/product search and inventory lookup for Daiso/Oliveyoung/CU/Emart24/Megabox/CGV services.",
            "server_url": "https://mcp.aka.page",
            "require_approval": "never"
        }
    ],
    input = "수납박스 검색해줘"
)

# %%
print(resp.output)
# Out:
# [McpListTools(id='mcpl_0b7519b7ca506d8b0069af9eda12708193816afd8a8e039fd9', server_label='daiso-mcp', tools=[McpListToolsTool(input_schema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'query': {'type': 'string', 'description': '검색할 제품명 또는 키워드'}, 'page': {'default': 1, 'description': '페이지 번호 (기본값: 1)', 'type': 'number'}, 'pageSize': {'default': 30, 'description': '페이지당 결과 수 (기본값: 30)', 'type': 'number'}}, 'required': ['query']}, name='daiso_search_products', annotations={'read_only': False}, description='다이소 제품을 검색합니다. 키워드로 제품을 검색할 수 있습니다.'), McpListToolsTool(input_schema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'keyword': {'description': '검색할 매장명 또는 주소 키워드 (예: 강남, 홍대)', 'type': 'string'}, 'sido': {'description': '시/도 (예: 서울, 경기, 부산)', 'type': 'string'}, 'gugun': {'description': '구/군 (예: 강남구, 마포구)', 'type': 'string'}, 'dong': {'description': '동 (예: 역삼동, 합정동)', 'type': 'string'}, 'limit': {'defaul
# ...

# %%
for event in client.responses.create(
    model = "gpt-4.1",
    tools = [
        {
            "type": "mcp",
            "server_label": "daiso-mcp",
            "server_description": "Daiso MCP server providing store/product search and inventory lookup for Daiso/Oliveyoung/CU/Emart24/Megabox/CGV services.",
            "server_url": "https://mcp.aka.page",
            "require_approval": "never"
        }
    ],
    input = "강남 CGV 시간표 알려줘",
    stream = True
):
    print(event)
# Out:
# ResponseCreatedEvent(response=Response(id='resp_0c91497b7cc8c9a60069afa2cf6cd08193a0b2de299880bf27', created_at=1773118159.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-2025-04-14', object='response', output=[], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[Mcp(server_label='daiso-mcp', type='mcp', allowed_tools=None, authorization=None, connector_id=None, headers=None, require_approval='never', server_description='Daiso MCP server providing store/product search and inventory lookup for Daiso/Oliveyoung/CU/Emart24/Megabox/CGV services.', server_url='https://mcp.aka.page')], top_p=1.0, background=False, completed_at=None, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='auto', status='in_progress', text=Respo
# ...
